# %% [markdown]
# ### Attribute Selection Criteria
#     Select attribute which partitions the data into subsets as “pure” as possible (i.e., into “homogeneous” data subsets)
# #### Measure the homogeneity of a subset
# * Classification Error
# * Gini Index
# * Entropy

# %% [markdown]
# data.jpg![image.png](attachment:image.png)

# %% [markdown]
# #### Entropy
#
# The average amount of information I needed to classify an object is given by the entropy measure
#
# ![](entropy.jpg)

# %% [markdown]
# Highest possible entropies

# %%
# 2 class example
print((-0.5*log(0.5,2)) + (-0.5*log(0.5,2)))

# 3 class example
print((-0.33*log(0.33,2)) + (-0.33*log(0.33,2)) + (-0.33*log(0.33,2)))

# 4 class example
print((-0.25*log(0.25,2)) + (-0.25*log(0.25,2)) +(-0.25*log(0.25,2)) + (-0.25*log(0.25,2)))
# Out:
# 1.0
# 1.5834674497121084
# 2.0

# %%
from math import log

# %% [markdown]
# Entropy before splitting

# %%
enBefore = (-6/13*log(6/13,2)) + (-7/13*log(7/13,2))
enBefore
# Out:
# 0.9957274520849256

# %% [markdown]
# After splitting with CCAVg

# %%
enCCLow = (-6/8*log(6/8,2)) + (-2/8*log(2/8,2))
enCCMed = (-3/3*log(3/3,2))
enCCHigh = (-2/2*log(2/2,2))

enCCTotal = 8/13*enCCLow + 3/13*enCCMed + 2/13*enCCHigh
print(enCCTotal)

InfGainCC = enBefore - enCCTotal
print(InfGainCC)
# Out:
# 0.4992480765902356
# 0.49647937549469

# %% [markdown]
# After splitting with Family

# %%
enF1 = (-2/4*log(2/4,2))+(-2/4*log(2/4,2))
enF2 = (-1/1*log(1/1,2))
enF3 = (-1/2*log(1/2,2))+(-1/2*log(1/2,2))
enF4 = (-3/6*log(3/6,2))+(-3/6*log(3/6,2))

enFTotal = 4/13*enF1 + 1/13*enF2 + 2/13*enF3 +  6/13*enF4
print(enFTotal)

InfGainF = enBefore - enFTotal
print(InfGainF)
# Out:
# 0.9230769230769231
# 0.0726505290080025

# %% [markdown]
# #### Gini Index
# ![](gini.png)

# %%
# Gini Index before splitting
giniBefore = 1-(6/13)**2 -(7/13)**2
print(giniBefore)

# Gini based on CCavg 

## {low}, {medium,high})
giniCCLow = 1-(6/8)**2-(2/8)**2
giniCCMedHigh = (1-(5/5)**2)

giniAfterl_mh = 8/13*giniCCLow+ 5/13*giniCCMedHigh
print(giniAfterl_mh)

## {medium}, {low, high}
giniCCMed = 1-(3/3)**2
giniCCLowHigh = 1-(6/10)**2-(4/10)**2

giniAfterm_lh = 3/13*giniCCMed + 10/13*giniCCLowHigh
print(giniAfterm_lh)

## {high}, {low, medium}
giniCCHigh = 1 - (2/2)**2
giniCCLowMed = 1 - (6/11)**2 - (5/11)**2

giniAfterh_lm = 2/13*giniCCHigh+11/13*giniCCLowMed
print(giniAfterh_lm)
# Out:
# 0.49704142011834324
# 0.23076923076923078
# 0.36923076923076925
# 0.4195804195804197
